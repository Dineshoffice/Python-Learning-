# %%
import pandas as pd

# %%
pwd
# Out:
# 'C:\\Users\\dinesh.kumar\\Desktop\\Python'

# %%
#pwd command  command Show from which location jupyter is pointing 
#Now to go goole and type csv git sample and download any csv file to read

# %%
#Now 1st copy addresses.csv into pointing folder and then user below command to read that file 
pd.read_csv('addresses.csv')
# Out:
#     id  location_id                   address_1  address_2  \
# 0    1            1       2600 Middlefield Road        NaN
# 1    2            2            24 Second Avenue        NaN
# 2    3            3            24 Second Avenue        NaN
# 3    4            4            24 Second Avenue        NaN
# 4    5            5            24 Second Avenue        NaN
# 5    6            6           800 Middle Avenue        NaN
# 6    7            7              500 Arbor Road        NaN
# 7    8            8           800 Middle Avenue        NaN
# 8    9            9       2510 Middlefield Road        NaN
# 9   10           10       1044 Middlefield Road        NaN
# 10  11           11         2140 Euclid Avenue.        NaN
# 11  12           12       1044 Middlefield Road  2nd Floor
# 12  13           13         399 Marine Parkway.        NaN
# 13  14           14          660 Veterans Blvd.        NaN
# 14  15           15        1500 Valencia Street        NaN
# ...

# %%
#it was copy and paste option and the  read file from that location 
#Now also you can upload file via Upload option then read it 
pd.read_csv('contacts.csv')
# Out:
#     id  location_id  organization_id  service_id                     name  \
# 0    1          1.0              NaN         NaN            Susan Houston
# 1    2          1.0              NaN         NaN       Christina Gonzalez
# 2    3          2.0              NaN         NaN             Brenda Brown
# 3    4          3.0              NaN         NaN       Howard Lader, LCSW
# 4    5          4.0              NaN         NaN       Kimberly Pesavento
# 5    6          5.0              NaN         NaN                Joe Bloom
# 6    7          6.0              NaN         NaN              Peter Olson
# 7    8          6.0              NaN         NaN             Bart Charlow
# 8    9          7.0              NaN         NaN             Bart Charlow
# 9   10          7.0              NaN         NaN             Barbara Kalt
# 10  11          8.0              NaN         NaN  Marilyn Baker-Venturini
# 11  12          8.0              NaN         NaN       Graciela Hernandez
# ...

# %%
#3rd way to read file from direct path such as 
pd.read_csv('C:/Users/dinesh.kumar/Downloads/ohana-api-master/ohana-api-master/data/sample-csv/locations.csv')
#here not \will not work as you need to convert fowword to backword slash
#if you wanto use forword slash then it should be double slash \\
# Out:
#     id  organization_id                                      accessibility  \
# 0    1                1       disabled_parking, ramp, restroom, wheelchair
# 1    2                1                                         wheelchair
# 2    3                1                                                NaN
# 3    4                1                                         wheelchair
# 4    5                1                                         wheelchair
# 5    6                2                       disabled_parking, wheelchair
# 6    7                2       ramp, restroom, disabled_parking, wheelchair
# 7    8                2                                                NaN
# 8    9                3                         ramp, restroom, wheelchair
# 9   10                3  elevator, tape_braille, ramp, restroom, disabl...
# 10  11                3                                               ramp
# ...

# %%
pd.read_csv('C:\\Users\\dinesh.kumar\\Downloads\\ohana-api-master\\ohana-api-master\\data\\sample-csv\\locations.csv')
# Out:
#     id  organization_id                                      accessibility  \
# 0    1                1       disabled_parking, ramp, restroom, wheelchair
# 1    2                1                                         wheelchair
# 2    3                1                                                NaN
# 3    4                1                                         wheelchair
# 4    5                1                                         wheelchair
# 5    6                2                       disabled_parking, wheelchair
# 6    7                2       ramp, restroom, disabled_parking, wheelchair
# 7    8                2                                                NaN
# 8    9                3                         ramp, restroom, wheelchair
# 9   10                3  elevator, tape_braille, ramp, restroom, disabl...
# 10  11                3                                               ramp
# ...

# %%
#Now if you want to hold that data in memory you can use following way
df=pd.read_csv('C:\\Users\\dinesh.kumar\\Downloads\\ohana-api-master\\ohana-api-master\\data\\sample-csv\\locations.csv')

# %%
#now i want to chekc data type of that variable
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
#now i wanto show 1st 2 records 
df.head(2)
# Out:
#    id  organization_id                                 accessibility  \
# 0   1                1  disabled_parking, ramp, restroom, wheelchair
# 1   2                1                                    wheelchair
#
#   admin_emails alternate_name  \
# 0          NaN            NaN
# 1          NaN            NaN
#
#                                          description email  \
# 0  A walk-in center for older adults that provide...   NaN
# 1  Provides training and job placement to eligibl...   NaN
#
#                                        languages   latitude   longitude  \
# 0                               Spanish, Tagalog  37.477227 -122.213221
# 1  Chinese (Mandarin), Tagalog, Italian, Spanish  37.563984 -122.325799
#
#                                name  \
# 0   Fair Oaks Adult Activity Center
# 1  Second Career Employment Program
#
#                                           short_desc  \
# 0  A multipurpose senior citizens' center serving...
# ...

# %%
df.head()# to show top 5 records
df.tail()#to show last 5 recrods
# Out:
#     id  organization_id                           accessibility admin_emails  \
# 17  18                5                cd, restroom, wheelchair          NaN
# 18  19                5              elevator, ramp, wheelchair          NaN
# 19  20                6                                     NaN          NaN
# 20  21                7                      elevator, restroom          NaN
# 21  22                8  disabled_parking, restroom, wheelchair  foo@bar.com
#
#    alternate_name                                        description  \
# 17            NaN  Provides free medical care to those in need. O...
# 18            NaN  Provides free medical and dental care to those...
# 19            NaN                                           no phone
# 20            NaN                              This is a description
# 21  The Test Spot  [NOTE THIS IS NOT A REAL ORGANIZATION--THIS IS...
#
#                email                                        languages  \
# ...

# %%
# here if you pass parameter inside head or tail then it will records such as 
df.tail(10)
# Out:
#     id  organization_id                           accessibility admin_emails  \
# 12  13                3                                     NaN          NaN
# 13  14                4                              wheelchair          NaN
# 14  15                4                              wheelchair          NaN
# 15  16                4                                     NaN          NaN
# 16  17                4                              wheelchair          NaN
# 17  18                5                cd, restroom, wheelchair          NaN
# 18  19                5              elevator, ramp, wheelchair          NaN
# 19  20                6                                     NaN          NaN
# 20  21                7                      elevator, restroom          NaN
# 21  22                8  disabled_parking, restroom, wheelchair  foo@bar.com
#
#    alternate_name                                        description  \
# ...

# %%
#here if you see Header is coming by default 1st line now if i want to ignore read 1st line as header then read file like this 
df=pd.read_csv('C:\\Users\\dinesh.kumar\\Downloads\\ohana-api-master\\ohana-api-master\\data\\sample-csv\\locations.csv',header=None)

# %%
df.head()
# Out:
#    0                1                                             2   \
# 0  id  organization_id                                 accessibility
# 1   1                1  disabled_parking, ramp, restroom, wheelchair
# 2   2                1                                    wheelchair
# 3   3                1                                           NaN
# 4   4                1                                    wheelchair
#
#              3               4   \
# 0  admin_emails  alternate_name
# 1           NaN             NaN
# 2           NaN             NaN
# 3           NaN             NaN
# 4           NaN             NaN
#
#                                                   5      6   \
# 0                                        description  email
# 1  A walk-in center for older adults that provide...    NaN
# 2  Provides training and job placement to eligibl...    NaN
# 3  Offers supportive counseling services to San M...    NaN
# ...

# %%
#get Colum  Name
df.heads()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-db8b27ec7c90> in <module>
#       1 #get Colum  Name
# ----> 2 df.heads()
#
# NameError: name 'df' is not defined

# %%
df=pd.read_csv('C:\\Users\\dinesh.kumar\\Downloads\\ohana-api-master\\ohana-api-master\\data\\sample-csv\\locations.csv')

# %%
df.head(2)
# Out:
#    id  organization_id                                 accessibility  \
# 0   1                1  disabled_parking, ramp, restroom, wheelchair
# 1   2                1                                    wheelchair
#
#   admin_emails alternate_name  \
# 0          NaN            NaN
# 1          NaN            NaN
#
#                                          description email  \
# 0  A walk-in center for older adults that provide...   NaN
# 1  Provides training and job placement to eligibl...   NaN
#
#                                        languages   latitude   longitude  \
# 0                               Spanish, Tagalog  37.477227 -122.213221
# 1  Chinese (Mandarin), Tagalog, Italian, Spanish  37.563984 -122.325799
#
#                                name  \
# 0   Fair Oaks Adult Activity Center
# 1  Second Career Employment Program
#
#                                           short_desc  \
# 0  A multipurpose senior citizens' center serving...
# ...

# %%
#get All Column names 
df.columns
# Out:
# Index(['id', 'organization_id', 'accessibility', 'admin_emails',
#        'alternate_name', 'description', 'email', 'languages', 'latitude',
#        'longitude', 'name', 'short_desc', 'transportation', 'website',
#        'virtual'],
#       dtype='object')

# %%
#get Data from Single column
df['organization_id']
# Out:
# 0     1
# 1     1
# 2     1
# 3     1
# 4     1
# 5     2
# 6     2
# 7     2
# 8     3
# 9     3
# 10    3
# 11    3
# 12    3
# 13    4
# 14    4
# 15    4
# 16    4
# 17    5
# 18    5
# 19    6
# 20    7
# 21    8
# Name: organization_id, dtype: int64

# %%
#now want to get more than one column
df['organization_id','accessibility']
#it will not work as it does not support multiple columns
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('organization_id', 'accessibility')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-f1febaf041e9> in <module>
# ...

# %%
#then we need to passs all columns as list
df[['organization_id', 'accessibility']]
# Out:
#     organization_id                                      accessibility
# 0                 1       disabled_parking, ramp, restroom, wheelchair
# 1                 1                                         wheelchair
# 2                 1                                                NaN
# 3                 1                                         wheelchair
# 4                 1                                         wheelchair
# 5                 2                       disabled_parking, wheelchair
# 6                 2       ramp, restroom, disabled_parking, wheelchair
# 7                 2                                                NaN
# 8                 3                         ramp, restroom, wheelchair
# 9                 3  elevator, tape_braille, ramp, restroom, disabl...
# 10                3                                               ramp
# 11                3         disabled_parking, elevator, ramp, restroom
# ...

# %%
type(df['organization_id'])
# Out:
# pandas.core.series.Series

# %%
#get Column's row 
df['organization_id'][3]
# Out:
# 1

# %%
df['accessibility'][2:4] #start from 2 and till 4th
# Out:
# 2           NaN
# 3    wheelchair
# Name: accessibility, dtype: object

# %%
df['accessibility'][0::2] #start from 0 and till end and increment 2
# Out:
# 0     disabled_parking, ramp, restroom, wheelchair
# 2                                              NaN
# 4                                       wheelchair
# 6     ramp, restroom, disabled_parking, wheelchair
# 8                       ramp, restroom, wheelchair
# 10                                            ramp
# 12                                             NaN
# 14                                      wheelchair
# 16                                      wheelchair
# 18                      elevator, ramp, wheelchair
# 20                              elevator, restroom
# Name: accessibility, dtype: object

# %%
#Now read file which differnt seprator lets say *
df1=pd.read_csv('contacts_Start.csv',sep='*')

# %%
df1.head()
# Out:
#    id  location_id  organization_id  service_id                name  \
# 0   1          1.0              NaN         NaN       Susan Houston
# 1   2          1.0              NaN         NaN  Christina Gonzalez
# 2   3          2.0              NaN         NaN        Brenda Brown
# 3   4          3.0              NaN         NaN  Howard Lader* LCSW
# 4   5          4.0              NaN         NaN  Kimberly Pesavento
#
#                               title email department
# 0  Director of Older Adult Services   NaN        NaN
# 1                   Center Director   NaN        NaN
# 2  Director* Second Career Services   NaN        NaN
# 3   Manager* Senior Peer Counseling   NaN        NaN
# 4            Director of Visitation   NaN        NaN

# %%
#read excel
df3=pd.read_excel("C:\\Users\\dinesh.kumar\\Desktop\\Python\\sample.xls")

# %%
df3.head()
# Out:
#    0 First Name  Last Name  Gender        Country  Age        Date    Id
# 0  1      Dulce      Abril  Female  United States   32  15/10/2017  1562
# 1  2       Mara  Hashimoto  Female  Great Britain   25  16/08/2016  1582
# 2  3     Philip       Gent    Male         France   36  21/05/2015  2587
# 3  4   Kathleen     Hanner  Female  United States   25  15/10/2017  3549
# 4  5    Nereida    Magwood  Female  United States   58  16/08/2016  2468

# %%
#now read from other sheet 
pd.read_excel("C:\\Users\\dinesh.kumar\\Desktop\\Python\\sample.xls",sheet_name='Sheet2')
# Out:
#    8   Earlean   Melgar  Female  United States  27  16/08/2016  2456
# 0  9  Vincenza  Weiland  Female  United States  40  21/05/2015  6548

# %%
#read from github
pd.read_csv('https://raw.githubusercontent.com/codeforamerica/ohana-api/master/data/sample-csv/addresses.csv')
# Out:
#     id  location_id                   address_1  address_2  \
# 0    1            1       2600 Middlefield Road        NaN
# 1    2            2            24 Second Avenue        NaN
# 2    3            3            24 Second Avenue        NaN
# 3    4            4            24 Second Avenue        NaN
# 4    5            5            24 Second Avenue        NaN
# 5    6            6           800 Middle Avenue        NaN
# 6    7            7              500 Arbor Road        NaN
# 7    8            8           800 Middle Avenue        NaN
# 8    9            9       2510 Middlefield Road        NaN
# 9   10           10       1044 Middlefield Road        NaN
# 10  11           11         2140 Euclid Avenue.        NaN
# 11  12           12       1044 Middlefield Road  2nd Floor
# 12  13           13         399 Marine Parkway.        NaN
# 13  14           14          660 Veterans Blvd.        NaN
# 14  15           15        1500 Valencia Street        NaN
# ...

# %%
pd.read_excel('https://docs.google.com/spreadsheets/d/1m4Iu7yZmv7-JqlaI6Q-9l8OrTOy2MJvWUjwJnspqReQ/edit#gid=1381074498')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-40e5e07cf441> in <module>
# ----> 1 pd.read_excel('https://docs.google.com/spreadsheets/d/1m4Iu7yZmv7-JqlaI6Q-9l8OrTOy2MJvWUjwJnspqReQ/edit#gid=1381074498')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     297                 )
#     298                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 299             return func(*args, **kwargs)
#     300
#     301         return wrapper
#
# ...

# %%
pd.read_html('https://www.basketball-reference.com/teams/')
# Out:
# [                Franchise   Lg     From       To  Yrs     G     W     L  \
#  0           Atlanta Hawks  NBA  1949-50  2021-22   73  5694  2809  2885
#  1           Atlanta Hawks  NBA  1968-69  2021-22   54  4276  2111  2165
#  2         St. Louis Hawks  NBA  1955-56  1967-68   13  1005   553   452
#  3         Milwaukee Hawks  NBA  1951-52  1954-55    4   281    91   190
#  4   Tri-Cities Blackhawks  NBA  1949-50  1950-51    2   132    54    78
#  ..                    ...  ...      ...      ...  ...   ...   ...   ...
#  80     Washington Bullets  NBA  1974-75  1996-97   23  1886   887   999
#  81        Capital Bullets  NBA  1973-74  1973-74    1    82    47    35
#  82      Baltimore Bullets  NBA  1963-64  1972-73   10   813   401   412
#  83        Chicago Zephyrs  NBA  1962-63  1962-63    1    80    25    55
#  84        Chicago Packers  NBA  1961-62  1961-62    1    80    18    62
#
#       W/L%  Plyfs  Div  Conf  Champ
#  0   0.493     47   12     0      1
# ...
